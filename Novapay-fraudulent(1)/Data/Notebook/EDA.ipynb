# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
print("All packages are working")

df =pd.read_csv("C:/Users/leona/OneDrive/Documents/July 10Analytic NOVA Project/Novapay-fraudulent/Data/Raw/novapay_fraud.csv")
